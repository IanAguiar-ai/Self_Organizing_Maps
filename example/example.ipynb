# %% [markdown]
# # Instructions for using SOM:

# %% [markdown]
# ## Import the library:

# %%
# !pip install git+https://github.com/IanAguiar-ai/Self_Organizing_Maps.git
# Out:
# Collecting git+https://github.com/IanAguiar-ai/Self_Organizing_Maps.git
#   Cloning https://github.com/IanAguiar-ai/Self_Organizing_Maps.git to /tmp/pip-req-build-7lmksjgg
#   Running command git clone --filter=blob:none --quiet https://github.com/IanAguiar-ai/Self_Organizing_Maps.git /tmp/pip-req-build-7lmksjgg
#   Resolved https://github.com/IanAguiar-ai/Self_Organizing_Maps.git to commit 43aa9d64632d50b340a8a885fc7cb93365892412
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from SOM==0.0.12) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from SOM==0.0.12) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from SOM==0.0.12) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from SOM==0.0.12) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->SOM==0.0.12) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->SOM==0.0.12) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->SOM==0.0.12) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->SOM==0.0.12) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->SOM==0.0.12) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->SOM==0.0.12) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->SOM==0.0.12) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->SOM==0.0.12) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->SOM==0.0.12) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->SOM==0.0.12) (1.16.0)
# Building wheels for collected packages: SOM
#   Building wheel for SOM (setup.py) ... done
#   Created wheel for SOM: filename=SOM-0.0.12-py3-none-any.whl size=11226 sha256=bde82cf46d51b802bbcaac6267630be9ae3e9bc14654606529b99e86b4c7558b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-oj_bk77s/wheels/48/c1/09/53c9fb0b2d4077feb46d5428bae8548177aa7cd3317945c61d
# Successfully built SOM
# Installing collected packages: SOM
# Successfully installed SOM-0.0.12

# %%
import som.som as som

# %% [markdown]
# If you have questions about functions:
#
# ```
# help(som)
# ```

# %% [markdown]
# ## Choosing any dataset to use SOM:

# %%
from sklearn.datasets import load_iris

iris = load_iris()

X = iris.data  # Features
y = iris.target  # Targets

# %% [markdown]
# ## Starting the SOM object:

# %%
SOM = som.create_SOM(5, learning = 0.05) #In this case, the SOM is a 10x10 grid, that is, there are 10 neurons
# Out:
# Use object n1_1, it is your starting point for SOM...
# To prepare the SOM for your data: n1_1.design_weights(YOUR_DATA)
# To start the SOM: n1_1.auto_organizing(epochs = 100)
#  This function return the list of neurons

# %% [markdown]
# ## Adding data to objects and arranging the grid on them:

# %%
som.n1_1.design_weights(X)
# Out:
# Adjust column 0
# Adjust column 1
# Adjust column 2
# Adjust column 3
# Add position of n0_0
# Add position of n0_1
# Add position of n0_2
# Add position of n0_3
# Add position of n0_4
# Add position of n1_0
# Add position of n1_1
# Add position of n1_2
# Add position of n1_3
# Add position of n1_4
# Add position of n2_0
# Add position of n2_1
# Add position of n2_2
# Add position of n2_3
# Add position of n2_4
# Add position of n3_0
# Add position of n3_1
# Add position of n3_2
# Add position of n3_3
# Add position of n3_4
# Add position of n4_0
# Add position of n4_1
# Add position of n4_2
# Add position of n4_3
# Add position of n4_4

# %% [markdown]
# Training the SOM:

# %%
som.n0_0.auto_organizing(epochs = 20, print_ = True) #20 interations

# %% [markdown]
# ## Graphs of neurons:

# %%
resp = som.n1_1.valley(normalize = True)

# %%
som.n1_1.amount_of_wins()

# %% [markdown]
# ## Neuron topology chart:

# %%
clusters = som.n1_1.predict(labels = list(y))

# %%
cluster_3_groups = som.adjust_clusters(clusters, groups = 6)

# %%
print(cluster_3_groups)
# Out:
# [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 5, 4, 4, 4, 4, 4, 4, 4, 4, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2, 3, 2, 1, 2, 1, 2, 1, 1, 2, 1, 1, 0, 1, 2, 1, 2, 2, 1, 1, 0, 1, 2, 1, 2, 1, 2, 1, 1, 2, 2, 2, 1, 1, 0, 1, 2, 2, 1, 1, 1, 2, 1, 1, 1, 2, 1, 1, 1, 2, 1, 1, 2]

# %% [markdown]
# ## Hierarchical classification by neuron:

# %%
dict_groups = som.n1_1.dendrogram(groups = 4)
# Out:
# Max distance to join neurons: 0.260282171382854
# Neuron 0: group 2
# Neuron 1: group 2
# Neuron 2: group 2
# Neuron 3: group 3
# Neuron 4: group 3
# Neuron 5: group 2
# Neuron 6: group 2
# Neuron 7: group 2
# Neuron 8: group 2
# Neuron 9: group 4
# Neuron 10: group 2
# Neuron 11: group 2
# Neuron 12: group 2
# Neuron 13: group 2
# Neuron 14: group 2
# Neuron 15: group 1
# Neuron 16: group 2
# Neuron 17: group 2
# Neuron 18: group 2
# Neuron 19: group 2
# Neuron 20: group 1
# Neuron 21: group 1
# Neuron 22: group 2
# Neuron 23: group 2
# Neuron 24: group 2

# %% [markdown]
# # Using library **metrics** to assess cluster quality:

# %%
# !pip install git+https://github.com/IanAguiar-ai/metrics.git
# Out:
# Collecting git+https://github.com/IanAguiar-ai/metrics.git
#   Cloning https://github.com/IanAguiar-ai/metrics.git to /tmp/pip-req-build-lw8z6fmq
#   Running command git clone --filter=blob:none --quiet https://github.com/IanAguiar-ai/metrics.git /tmp/pip-req-build-lw8z6fmq
#   Resolved https://github.com/IanAguiar-ai/metrics.git to commit c7b50f89d88ec2fbec32bdc7f5963ee5b8586e92
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from metrics==0.0.11) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from metrics==0.0.11) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from metrics==0.0.11) (1.5.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from metrics==0.0.11) (1.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->metrics==0.0.11) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->metrics==0.0.11) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->metrics==0.0.11) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->metrics==0.0.11) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->metrics==0.0.11) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->metrics==0.0.11) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->metrics==0.0.11) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->metrics==0.0.11) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->metrics==0.0.11) (2022.7.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->metrics==0.0.11) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->metrics==0.0.11) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->metrics==0.0.11) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->metrics==0.0.11) (1.16.0)
# Building wheels for collected packages: metrics
#   Building wheel for metrics (setup.py) ... done
#   Created wheel for metrics: filename=metrics-0.0.11-py3-none-any.whl size=17649 sha256=e0781c1ecb3e9cffdb63ffe26d0f91448abb50eab67d4a4dc51fb4b379871f60
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6thjqcm1/wheels/c7/48/53/4f50b27b511fdefedb30381ad08615e2dc2bae6ab5a0986841
# Successfully built metrics
# Installing collected packages: metrics
# Successfully installed metrics-0.0.11

# %%
from mutual_information import metrics as mtr

# %%
help(mtr.mutual_information)
# Out:
# Help on function mutual_information in module mutual_information.metrics:
#
# mutual_information(x: list, y: list = None, base: int = 2, **args)
#     Calculates mutual information
#
#     :param x: Sample observation list 1
#     :type x: list
#
#     :param y: Sample observation list 2
#     :type y: list
#
#     :param base: Base of logarithm, a priori is 2
#     :type base: int
#
#     Other parameters:
#     :param print: Whether the result will be printed on the screen.
#     :type print: bool
#
#     ▬ return:
#     • float: mutual information
#     • float: normalized mutual information

# %%
mtr.mutual_information(cluster_3_groups, list(y))
# Out:
# [0, 0, 0, 0, 49, 1] -- 0
# [0, 0, 45, 5, 0, 0] -- 1
# [3, 29, 18, 0, 0, 0] -- 2
#  |  |  |  |  |  |
#  0  1  2  3  4  5
#
# Certainty knowing the result of X knowing Y: 0.7778098237185687 ~ 1 in 1.2856613139946989
# Certainty knowing the result of Y knowing X: 0.6536253309254235 ~ 1 in 1.529928466181334
#
# Entropy in logarithm base 2:
# X: 1.8359160613129488 -> 2**X = 3.56998017174757
# Y: 1.584962500721156 -> 2**Y = 3.0
# Mutual Information in base 2: 1.222451861923171
# Normalized Mutual Information: 0.7147005307293242
# --------------------------------------------------
# (1.222451861923171, 0.7147005307293242)
